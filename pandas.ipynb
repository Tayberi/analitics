# %%
# !ls
# Out:
# df3.csv  sample_data

# %%
# Запустите эту ячейку
import pandas as pd
# %matplotlib inline

df3 = pd.read_csv('df3.csv')
print(len(df3))
print(df3.head())
# Out:
# 500
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %%
df3
# Out:
#          weekday  produced  defective
# 0       1.Monday        73          7
# 1      2.Tuesday        75         10
# 2    3.Wednesday        86          7
# 3     4.Thursday        64          7
# 4       5.Friday        70          6
# ..           ...       ...        ...
# 495     1.Monday        62          8
# 496    2.Tuesday        73         10
# 497  3.Wednesday        79          7
# 498   4.Thursday        78          6
# 499     5.Friday        55          5
#
# [500 rows x 3 columns]

# %% [markdown]
# Эти данные представляют собой заводские производственные показатели и сообщенное количество дефектов в определенные дни недели.

# %% [markdown]
# ### 1. Воссоздайте этот график разброса «произведенных» и «дефектных»  деталей. Обратите внимание на цвет и размер точек. Также обратите внимание на размер картинки. Сможете ли растянуть его аналогичным образом?

# %%
# ВАШ КОД
df3.plot()
df3.describe()
# Out:
#          produced   defective
# count  500.000000  500.000000
# mean    73.518000    7.044000
# std      9.120309    1.617187
# min     53.000000    4.000000
# 25%     67.000000    6.000000
# 50%     73.000000    7.000000
# 75%     80.000000    8.000000
# max     95.000000   10.000000

# %%
df3.plot.scatter('produced', 'defective', c='red', figsize=(10,4))

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 2. Создайте гистограмму для колонки 'produced'

# %%
# ВАШ КОД

# %%
type(df3.produced)
# Out:
# pandas.core.series.Series

# %%
df3.produced.plot.hist()

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 3. Перерисуйте гистограмму как на рисунке ниже

# %%
# ВАШ КОД

# %%
df3.produced.plot.hist(edgecolor = 'k')

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 4. Создайте boxplot для 'produced' в каждый из дней недели 'weekday' (используйте группировку)

# %%
# ВАШ КОД
df3[['produced', 'weekday']].boxplot(by='weekday', grid=False)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 5.Создайте KDE (ядерная оценка плотности) для колонки 'defective'

# %%
# ВАШ КОД
df3.defective.plot.kde()

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 6. Видоизмените график KDE, как на рисунке ниже

# %%
# ВАШ КОД
df3.defective.plot.kde(ls='dashed', lw=5)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 7. Для первых 30 строк постройте графики областей «произведенных» и «дефектных» деалей. (используйте .loc)

# %%
# ВАШ КОД
df3.loc[:30].plot.area(alpha=0.38, stacked=False)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# Поменяйте расположение легенды на графике (как показано ниже)

# %%
# ВАШ КОД
df3.loc[:30].plot.area(alpha=0.38, stacked=False).legend(bbox_to_anchor=(1.02, 0.6), loc='upper left', borderaxespad=0)

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ
